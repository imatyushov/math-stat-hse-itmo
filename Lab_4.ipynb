# %% [markdown]
# <a href="https://colab.research.google.com/github/imatyushov/math-stat-hse-itmo/blob/main/Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Снимок экрана 2024-11-02 в 15.57.05.png](data:image/png;base64,...)
